# %% [markdown]
# # Análisis y Limpieza de Datos Educativos
#
# ## Descripción de la Base de Datos
#
# La base de datos **MEN_ESTADÍSTICAS EN EDUCACIÓN EN PREESCOLAR, BÁSICA Y MEDIA POR MUNICIPIO** contiene información relacionadan con los niveles educativos de **preescolar**, **básica** y **media**. La información está desglosada por municipio y presenta indicadores sectoriales que permiten analizar la cobertura educativa, deserción, repitencia, y aprobación en diferentes niveles.
#
# La base abarca los años **2011 a 2023**, y los datos se presentan sin valores atípicos. Además, para las tasas de cobertura bruta y neta de los años **2019** y **2018**, los cálculos se realizaron utilizando las **proyecciones de población** derivadas del **Censo 2018**.
#
# En este archivo se realizará un análisis y limpieza del conjunto de datos educativos proporcionado por el DANE. Los datos contienen información sobre tasas de matrícula, deserción, repitencia y cobertura educativa en los niveles preescolar, básica y media, desglosados por municipio y año.
#
# El proceso se centrará en limpiar, normalizar y transformar las variables para hacer que los datos sean adecuados para análisis posteriores en SQL.

# %%
## Vamos a importar la librerias necesarias

import pandas as pd
import requests
pd.set_option('display.max_columns', None) ## muestra todos los datos

# %% [markdown]
# ### 1. Extraer Datos

# %%
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"
print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ✅ ¡Extracción exitosa! Se cargaron 14585 filas.
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
# 3       3831     Vaupés (ETC)          10986                   59.57
# 4       3831     Vaupés (ETC)           1228                    51.3
#
#   cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 0          62.62                     44.19                   63.33
# 1          53.27                     33.91                   48.89
# 2          32.52                     17.58                   25.33
# 3          59.57                     42.76                   55.95
# 4           51.3                     76.32                   52.29
#
#   cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 0                     51.53                40.23            66.8
# 1                      44.9                 21.3           62.98
# 2                     26.43                10.75           38.58
# 3                     43.51                17.06           70.65
# 4                     33.71                11.94           55.54
#
#   cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0                      58.14                    72.86
# 1                       54.2                    65.19
# 2                      36.36                    37.28
# 3                       64.9                    76.96
# 4                      92.11                    65.21
#
#   cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                      66.87                 56.32      1.19
# 1                       69.6                 48.54      5.56
# 2                       46.1                 26.16      7.85
# 3                      72.92                 53.12      3.95
# 4                      51.12                 27.36      8.36
#
#   deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                    0               1.31                    0
# 1                 6.95               4.99                 6.11
# 2                   15               8.43                 6.36
# 3                 2.27               1.84                 6.77
# 4                 4.29               3.05                15.72
#
#   deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0            4.08      92.26                     0               96.73
# 1            5.26      87.67                     0                87.9
# 2            4.69      82.68                  3.33               84.64
# 3            5.47      90.71                  0.57               94.12
# 4           14.55       82.4                     0               89.63
#
#   aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                 83.49            93.88        6.55                      0
# 1                  84.5            92.98        6.78                      0
# 2                 79.51             87.5        9.47                   3.33
# 3                 84.91            89.93        5.34                   0.57
# 4                    69            78.18        9.24                      0
#
#   reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                 1.96                  16.51              2.04       9.52
# 1                 7.11                   9.39              1.75       9.34
# 2                 6.93                  14.13              7.81       8.65
# 3                 4.04                   8.33               4.6      16.18
# 4                 7.32                  15.28              7.27       9.24
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
# 4                  2.86                7.62                 14.85
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0             2.04                      NaN                         NaN
# 1             3.16                      NaN                         NaN
# 2             1.54                      NaN                         NaN
# 3             7.18                      NaN                         NaN
# 4             3.64                      NaN                         NaN

# %% [markdown]
# ### 2. Conocer los tipos de variables
# Conocer los tipos de variables te permite realizar un análisis adecuado, limpiar los datos correctamente.

# %%
df_raw.dtypes
# Out:
# a_o                            object
# c_digo_municipio               object
# municipio                      object
# c_digo_departamento            object
# departamento                   object
# c_digo_etc                     object
# etc                            object
# poblaci_n_5_16                 object
# tasa_matriculaci_n_5_16        object
# cobertura_neta                 object
# cobertura_neta_transici_n      object
# cobertura_neta_primaria        object
# cobertura_neta_secundaria      object
# cobertura_neta_media           object
# cobertura_bruta                object
# cobertura_bruta_transici_n     object
# cobertura_bruta_primaria       object
# cobertura_bruta_secundaria     object
# cobertura_bruta_media          object
# deserci_n                      object
# deserci_n_transici_n           object
# deserci_n_primaria             object
# deserci_n_secundaria           object
# deserci_n_media                object
# aprobaci_n                     object
# aprobaci_n_transici_n          object
# aprobaci_n_primaria            object
# aprobaci_n_secundaria          object
# aprobaci_n_media               object
# reprobaci_n                    object
# reprobaci_n_transici_n         object
# reprobaci_n_primaria           object
# reprobaci_n_secundaria         object
# reprobaci_n_media              object
# repitencia                     object
# repitencia_transici_n          object
# repitencia_primaria            object
# repitencia_secundaria          object
# repitencia_media               object
# tama_o_promedio_de_grupo       object
# sedes_conectadas_a_internet    object
# dtype: object

# %% [markdown]
# ### 3. Convertir las variables numericas en **Tipo Float**, para poder trabajarlas

# %%
columnas_numericas = [
    'poblaci_n_5_16', 'tasa_matriculaci_n_5_16', 'cobertura_neta', 'cobertura_neta_transici_n',
    'cobertura_neta_primaria', 'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
    'cobertura_bruta_transici_n', 'cobertura_bruta_primaria', 'cobertura_bruta_secundaria',
    'cobertura_bruta_media', 'deserci_n', 'deserci_n_transici_n', 'deserci_n_primaria', 'deserci_n_secundaria',
    'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria', 'aprobaci_n_secundaria',
    'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n', 'reprobaci_n_primaria', 'reprobaci_n_secundaria',
    'reprobaci_n_media', 'repitencia', 'repitencia_transici_n', 'repitencia_primaria', 'repitencia_secundaria',
    'repitencia_media', 'tama_o_promedio_de_grupo', 'sedes_conectadas_a_internet'
]

# Convertir las columnas numéricas a float
df_raw[columnas_numericas] = df_raw[columnas_numericas].apply(pd.to_numeric, errors='coerce')
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#   c_digo_etc              etc  poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)           503.0                    62.62
# 1       3830   Guaviare (ETC)          4438.0                    53.27
# 2       3830   Guaviare (ETC)          2014.0                    32.52
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0           62.62                      44.19                    63.33
# 1           53.27                      33.91                    48.89
# 2           32.52                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                       NaN
# 1                   8.48              3.16                       NaN
# 2                  10.25              1.54                       NaN
#
#    sedes_conectadas_a_internet
# 0                          NaN
# 1                          NaN
# 2                          NaN

# %% [markdown]
# Vamos a comprobar

# %%
df_raw.dtypes
# Out:
# a_o                             object
# c_digo_municipio                object
# municipio                       object
# c_digo_departamento             object
# departamento                    object
# c_digo_etc                      object
# etc                             object
# poblaci_n_5_16                 float64
# tasa_matriculaci_n_5_16        float64
# cobertura_neta                 float64
# cobertura_neta_transici_n      float64
# cobertura_neta_primaria        float64
# cobertura_neta_secundaria      float64
# cobertura_neta_media           float64
# cobertura_bruta                float64
# cobertura_bruta_transici_n     float64
# cobertura_bruta_primaria       float64
# cobertura_bruta_secundaria     float64
# cobertura_bruta_media          float64
# deserci_n                      float64
# deserci_n_transici_n           float64
# deserci_n_primaria             float64
# deserci_n_secundaria           float64
# deserci_n_media                float64
# aprobaci_n                     float64
# aprobaci_n_transici_n          float64
# aprobaci_n_primaria            float64
# aprobaci_n_secundaria          float64
# aprobaci_n_media               float64
# reprobaci_n                    float64
# reprobaci_n_transici_n         float64
# reprobaci_n_primaria           float64
# reprobaci_n_secundaria         float64
# reprobaci_n_media              float64
# repitencia                     float64
# repitencia_transici_n          float64
# repitencia_primaria            float64
# repitencia_secundaria          float64
# repitencia_media               float64
# tama_o_promedio_de_grupo       float64
# sedes_conectadas_a_internet    float64
# dtype: object

# %% [markdown]
# ### 4. Normalizar datos númericos que estan en (%)

# %%
porcentaje_columnas = [
    'tasa_matriculaci_n_5_16', 'cobertura_neta', 'cobertura_neta_transici_n', 
    'cobertura_neta_primaria', 'cobertura_neta_secundaria', 'cobertura_neta_media',
    'cobertura_bruta', 'cobertura_bruta_transici_n', 'cobertura_bruta_primaria', 
    'cobertura_bruta_secundaria', 'cobertura_bruta_media', 'deserci_n', 
    'deserci_n_transici_n', 'deserci_n_primaria', 'deserci_n_secundaria', 'deserci_n_media', 
    'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria', 'aprobaci_n_secundaria', 
    'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n', 'reprobaci_n_primaria', 
    'reprobaci_n_secundaria', 'reprobaci_n_media', 'repitencia', 'repitencia_transici_n', 
    'repitencia_primaria', 'repitencia_secundaria', 'repitencia_media',
    'sedes_conectadas_a_internet'  # Incluimos la columna que faltaba
]

# esta linea nomaliza los valores,el apply aplica la función sobre acda columna para cada argumento x
df_raw[porcentaje_columnas] = df_raw[porcentaje_columnas].apply(lambda x: x / 100)
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#   c_digo_etc              etc  poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)           503.0                   0.6262
# 1       3830   Guaviare (ETC)          4438.0                   0.5327
# 2       3830   Guaviare (ETC)          2014.0                   0.3252
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0          0.6262                     0.4419                   0.6333
# 1          0.5327                     0.3391                   0.4889
# 2          0.3252                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                0.0000              0.0131                0.0000
# 1                0.0695              0.0499                0.0611
# 2                0.1500              0.0843                0.0636
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0           0.0408      0.9226                 0.0000               0.9673
# 1           0.0526      0.8767                 0.0000               0.8790
# 2           0.0469      0.8268                 0.0333               0.8464
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                 0.8349            0.9388       0.0655
# 1                 0.8450            0.9298       0.0678
# 2                 0.7951            0.8750       0.0947
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                  0.0000                0.0196                  0.1651
# 1                  0.0000                0.0711                  0.0939
# 2                  0.0333                0.0693                  0.1413
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0             0.0204      0.0952                 0.0000               0.1046
# 1             0.0175      0.0934                 0.0695               0.1184
# 2             0.0781      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                 0.1376            0.0204                       NaN
# 1                 0.0848            0.0316                       NaN
# 2                 0.1025            0.0154                       NaN
#
#    sedes_conectadas_a_internet
# 0                          NaN
# 1                          NaN
# 2                          NaN

# %% [markdown]
# ### 5. Identificar Valores Nulos

# %%
df_raw.isnull().sum().sort_values(ascending=False)
# Out:
# tama_o_promedio_de_grupo       7013
# sedes_conectadas_a_internet    6817
# deserci_n_transici_n            903
# deserci_n_media                 734
# deserci_n_secundaria            270
# deserci_n_primaria              242
# repitencia_transici_n           159
# repitencia_secundaria           152
# repitencia_primaria             148
# reprobaci_n_media               145
# repitencia                      143
# deserci_n                       142
# repitencia_media                139
# cobertura_bruta_media           127
# tasa_matriculaci_n_5_16         115
# cobertura_neta                  111
# reprobaci_n_secundaria          106
# aprobaci_n_media                101
# cobertura_bruta_transici_n       97
# reprobaci_n_primaria             97
# cobertura_neta_secundaria        94
# reprobaci_n_transici_n           93
# aprobaci_n_transici_n            93
# cobertura_neta_media             93
# cobertura_neta_primaria          91
# cobertura_bruta_secundaria       88
# reprobaci_n                      86
# cobertura_bruta_primaria         81
# cobertura_bruta                  68
# aprobaci_n_secundaria            54
# cobertura_neta_transici_n        52
# aprobaci_n                       25
# aprobaci_n_primaria              25
# poblaci_n_5_16                    7
# c_digo_etc                        0
# c_digo_departamento               0
# etc                               0
# municipio                         0
# c_digo_municipio                  0
# a_o                               0
# departamento                      0
# dtype: int64

# %% [markdown]
# - Vamos a eliminar TAMAÑO_PROMEDIO_DE_GRUPO y SEDES_CONECTADAS_A_INTERNET.
#
# Decidimos eliminar las columnas **TAMAÑO_PROMEDIO_DE_GRUPO** y **SEDES_CONECTADAS_A_INTERNET** debido a que más del **50%** de sus valores están nulos. Además,  estas variables no son tan relevantes para los objetivos principales de nuestra investigación.

# %%
# Eliminar columnas con demasiados nulos 
df_raw.drop(columns=['tama_o_promedio_de_grupo', 'sedes_conectadas_a_internet'], inplace=True)
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#   c_digo_etc              etc  poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)           503.0                   0.6262
# 1       3830   Guaviare (ETC)          4438.0                   0.5327
# 2       3830   Guaviare (ETC)          2014.0                   0.3252
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0          0.6262                     0.4419                   0.6333
# 1          0.5327                     0.3391                   0.4889
# 2          0.3252                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                0.0000              0.0131                0.0000
# 1                0.0695              0.0499                0.0611
# 2                0.1500              0.0843                0.0636
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0           0.0408      0.9226                 0.0000               0.9673
# 1           0.0526      0.8767                 0.0000               0.8790
# 2           0.0469      0.8268                 0.0333               0.8464
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                 0.8349            0.9388       0.0655
# 1                 0.8450            0.9298       0.0678
# 2                 0.7951            0.8750       0.0947
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                  0.0000                0.0196                  0.1651
# 1                  0.0000                0.0711                  0.0939
# 2                  0.0333                0.0693                  0.1413
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0             0.0204      0.0952                 0.0000               0.1046
# 1             0.0175      0.0934                 0.0695               0.1184
# 2             0.0781      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media
# 0                 0.1376            0.0204
# 1                 0.0848            0.0316
# 2                 0.1025            0.0154

# %% [markdown]
# - Analizando nuevamente la información se decide eliminar tasa de deserción en transición y media, porque aunque los valores nulos no son mayores al 50%, son muchos y no lo usaremos para nuetsro analisis.

# %%
df_raw.drop(columns=['deserci_n_transici_n', 'deserci_n_media'], inplace=True)
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#   c_digo_etc              etc  poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)           503.0                   0.6262
# 1       3830   Guaviare (ETC)          4438.0                   0.5327
# 2       3830   Guaviare (ETC)          2014.0                   0.3252
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0          0.6262                     0.4419                   0.6333
# 1          0.5327                     0.3391                   0.4889
# 2          0.3252                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0              0.0131                0.0000      0.9226
# 1              0.0499                0.0611      0.8767
# 2              0.0843                0.0636      0.8268
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                 0.0000               0.9673                 0.8349
# 1                 0.0000               0.8790                 0.8450
# 2                 0.0333               0.8464                 0.7951
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0            0.9388       0.0655                  0.0000
# 1            0.9298       0.0678                  0.0000
# 2            0.8750       0.0947                  0.0333
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                0.0196                  0.1651             0.0204
# 1                0.0711                  0.0939             0.0175
# 2                0.0693                  0.1413             0.0781
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0      0.0952                 0.0000               0.1046
# 1      0.0934                 0.0695               0.1184
# 2      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media
# 0                 0.1376            0.0204
# 1                 0.0848            0.0316
# 2                 0.1025            0.0154

# %% [markdown]
# ### 6. Imputaremos las siguientes variables utilizando la **mediana** para reemplazar los valores faltantes.

# %%
imputacion_mediana = [
    'deserci_n_secundaria', 'deserci_n_primaria', 'repitencia_transici_n', 'repitencia_secundaria', 
    'repitencia_primaria', 'reprobaci_n_media', 'repitencia', 'deserci_n', 'repitencia_media', 
    'cobertura_bruta_media', 'tasa_matriculaci_n_5_16', 'cobertura_neta', 'reprobaci_n_secundaria', 
    'aprobaci_n_media', 'cobertura_bruta_transici_n', 'reprobaci_n_primaria', 'cobertura_neta_secundaria', 
    'cobertura_neta_media', 'reprobaci_n_transici_n', 'aprobaci_n_transici_n', 'cobertura_neta_primaria', 
    'cobertura_bruta_secundaria', 'reprobaci_n', 'cobertura_bruta_primaria', 'cobertura_bruta', 
    'aprobaci_n_secundaria', 'cobertura_neta_transici_n', 'aprobaci_n_primaria', 'aprobaci_n', 
    'poblaci_n_5_16'
]

for col in imputacion_mediana:
    df_raw[col].fillna(df_raw[col].median())

# %%
## Prueba
### Valores nulos
df_raw.isnull().sum().sort_values(ascending=False)
# Out:
# deserci_n_secundaria          270
# deserci_n_primaria            242
# repitencia_transici_n         159
# repitencia_secundaria         152
# repitencia_primaria           148
# reprobaci_n_media             145
# repitencia                    143
# deserci_n                     142
# repitencia_media              139
# cobertura_bruta_media         127
# tasa_matriculaci_n_5_16       115
# cobertura_neta                111
# reprobaci_n_secundaria        106
# aprobaci_n_media              101
# reprobaci_n_primaria           97
# cobertura_bruta_transici_n     97
# cobertura_neta_secundaria      94
# aprobaci_n_transici_n          93
# cobertura_neta_media           93
# reprobaci_n_transici_n         93
# cobertura_neta_primaria        91
# cobertura_bruta_secundaria     88
# reprobaci_n                    86
# cobertura_bruta_primaria       81
# cobertura_bruta                68
# aprobaci_n_secundaria          54
# cobertura_neta_transici_n      52
# aprobaci_n_primaria            25
# aprobaci_n                     25
# poblaci_n_5_16                  7
# departamento                    0
# municipio                       0
# c_digo_municipio                0
# a_o                             0
# c_digo_departamento             0
# c_digo_etc                      0
# etc                             0
# dtype: int64

# %% [markdown]
# - Revisar estadísticas descriptivas después de imputar.

# %%
df_raw[imputacion_mediana].describe()
# Out:
#        deserci_n_secundaria  deserci_n_primaria  repitencia_transici_n  \
# count          14315.000000        14343.000000           14426.000000
# mean               0.045779            0.027567               0.009432
# std                0.031029            0.020478               0.024151
# min                0.000000            0.000000               0.000000
# 25%                0.023500            0.012600               0.000000
# 50%                0.040400            0.023200               0.000000
# 75%                0.062000            0.037800               0.009300
# max                0.471400            0.183100               0.500000
#
#        repitencia_secundaria  repitencia_primaria  reprobaci_n_media  \
# count           14433.000000         14437.000000       14440.000000
# mean                0.043265             0.031695           0.041308
# std                 0.045487             0.036441           0.042118
# min                 0.000000             0.000000           0.000000
# 25%                 0.007300             0.005900           0.006700
# 50%                 0.027400             0.018800           0.031000
# 75%                 0.068200             0.045900           0.064000
# max                 0.550700             0.507600           0.678600
#
#          repitencia     deserci_n  repitencia_media  cobertura_bruta_media  \
# count  14442.000000  14443.000000      14446.000000           14458.000000
# mean       0.032995      0.034899          0.016979               0.758558
# std        0.033698      0.021726          0.022841               0.269927
# min        0.000000      0.000000          0.000000               0.000000
# 25%        0.007200      0.019300          0.000000               0.596125
# 50%        0.021600      0.031300          0.008700               0.752500
# 75%        0.050900      0.046600          0.025600               0.903775
# max        0.374700      0.279000          0.364500               4.896200
#
#        tasa_matriculaci_n_5_16  cobertura_neta  reprobaci_n_secundaria  \
# count             14470.000000    14474.000000            14479.000000
# mean                  0.849719        0.855532                0.068090
# std                   0.185891        0.169324                0.061535
# min                   0.000000        0.000000                0.000000
# 25%                   0.748500        0.768900                0.007200
# 50%                   0.853300        0.864000                0.061600
# 75%                   0.953800        0.945400                0.108300
# max                   2.790300        2.645400                0.769700
#
#        aprobaci_n_media  cobertura_bruta_transici_n  reprobaci_n_primaria  \
# count      14484.000000                14488.000000          14488.000000
# mean           0.921405                    0.871303              0.038848
# std            0.070143                    0.255659              0.038025
# min            0.000000                    0.000000              0.000000
# 25%            0.894275                    0.714300              0.004100
# 50%            0.932900                    0.852100              0.033300
# 75%            0.964300                    1.000000              0.060000
# max            1.000000                    2.592900              0.519700
#
#        cobertura_neta_secundaria  cobertura_neta_media  \
# count               14491.000000           14492.00000
# mean                    0.699056               0.40747
# std                     0.188309               0.15629
# min                     0.000000               0.00000
# 25%                     0.603950               0.31110
# 50%                     0.709000               0.41165
# 75%                     0.805600               0.50540
# max                     2.294400               1.70260
#
#        reprobaci_n_transici_n  aprobaci_n_transici_n  cobertura_neta_primaria  \
# count            14492.000000           14492.000000             14494.000000
# mean                 0.004868               0.004868                 0.825667
# std                  0.016533               0.016533                 0.172036
# min                  0.000000               0.000000                 0.000000
# 25%                  0.000000               0.000000                 0.732100
# 50%                  0.000000               0.000000                 0.828300
# 75%                  0.002200               0.002200                 0.919375
# max                  0.527100               0.527100                 2.549600
#
#        cobertura_bruta_secundaria   reprobaci_n  cobertura_bruta_primaria  \
# count                14497.000000  14499.000000              14504.000000
# mean                     1.033824      0.047573                  1.073010
# std                      1.584949      0.039995                  1.548438
# min                      0.000000      0.000000                  0.000000
# 25%                      0.865100      0.009200                  0.898000
# 50%                      1.015400      0.045200                  1.033200
# 75%                      1.157400      0.074200                  1.177000
# max                    110.650000      0.493900                109.360000
#
#        cobertura_bruta  aprobaci_n_secundaria  cobertura_neta_transici_n  \
# count     14517.000000           14531.000000               14533.000000
# mean          0.996951               0.883587                   0.576924
# std           1.486799               0.079718                   0.161986
# min           0.000000               0.000000                   0.000000
# 25%           0.856800               0.836300                   0.475000
# 50%           0.975000               0.891000                   0.579000
# 75%           1.092600               0.944700                   0.680000
# max         104.480000               1.000000                   1.504700
#
#        aprobaci_n_primaria    aprobaci_n  poblaci_n_5_16
# count         14560.000000  14560.000000    1.457800e+04
# mean              0.932135      0.916081    1.018325e+04
# std               0.052161      0.053278    1.436032e+05
# min               0.000000      0.000000    1.000000e+00
# 25%               0.905600      0.884400    1.165000e+03
# 50%               0.938700      0.920200    2.640000e+03
# 75%               0.969500      0.955900    5.868250e+03
# max               1.000000      1.000000    9.548263e+06

# %% [markdown]
# - Las variables relacionadas con cobertura educativa y tasa de matrícula pueden superar el 100% debido a factores como extraedad (estudiantes fuera de la edad teórica para un nivel educativo) y flujos migratorios no capturados en las proyecciones de población. Esto es común en áreas con alta demanda social o movimientos poblacionales.

# %% [markdown]
# ### 7. Identificar que datos tiene codigo municipio

# %%
# AÑO
df_raw['a_o'].value_counts().sort_index()
# Out:
# a_o
# 2011    1122
# 2012    1122
# 2013    1122
# 2014    1122
# 2015    1122
# 2016    1122
# 2017    1122
# 2018    1122
# 2019    1123
# 2020    1122
# 2021    1122
# 2022    1121
# 2023    1121
# Name: count, dtype: int64

# %%
## necesito ver si existen datos repetidos, para esto voy a tomar código municipio y el año
municipio_ano = df_raw.groupby(['a_o', 'c_digo_municipio']).size().reset_index(name='count')
municipio_ano.head(3)
# Out:
#     a_o c_digo_municipio  count
# 0  2011            11001      1
# 1  2011            13001      1
# 2  2011            13006      1

# %% [markdown]
# No hay repetidos

# %% [markdown]
# ### 8.Vamos a eliminar `c_digo_etc` y `etc` porque no nos funcionan para el análisis.

# %%
df_raw.drop(columns=['c_digo_etc', 'etc'], inplace=True)

# %%
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                   0.6262          0.6262
# 1          4438.0                   0.5327          0.5327
# 2          2014.0                   0.3252          0.3252
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                     0.4419                   0.6333
# 1                     0.3391                   0.4889
# 2                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0              0.0131                0.0000      0.9226
# 1              0.0499                0.0611      0.8767
# 2              0.0843                0.0636      0.8268
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                 0.0000               0.9673                 0.8349
# 1                 0.0000               0.8790                 0.8450
# 2                 0.0333               0.8464                 0.7951
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0            0.9388       0.0655                  0.0000
# 1            0.9298       0.0678                  0.0000
# 2            0.8750       0.0947                  0.0333
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                0.0196                  0.1651             0.0204
# 1                0.0711                  0.0939             0.0175
# 2                0.0693                  0.1413             0.0781
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0      0.0952                 0.0000               0.1046
# 1      0.0934                 0.0695               0.1184
# 2      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media
# 0                 0.1376            0.0204
# 1                 0.0848            0.0316
# 2                 0.1025            0.0154

# %% [markdown]
# ### 9. Necesito crear la variable: `total matriculados`

# %%
df_raw['total_matriculados'] = df_raw['poblaci_n_5_16'] * df_raw['tasa_matriculaci_n_5_16']
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                   0.6262          0.6262
# 1          4438.0                   0.5327          0.5327
# 2          2014.0                   0.3252          0.3252
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                     0.4419                   0.6333
# 1                     0.3391                   0.4889
# 2                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0              0.0131                0.0000      0.9226
# 1              0.0499                0.0611      0.8767
# 2              0.0843                0.0636      0.8268
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                 0.0000               0.9673                 0.8349
# 1                 0.0000               0.8790                 0.8450
# 2                 0.0333               0.8464                 0.7951
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0            0.9388       0.0655                  0.0000
# 1            0.9298       0.0678                  0.0000
# 2            0.8750       0.0947                  0.0333
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                0.0196                  0.1651             0.0204
# 1                0.0711                  0.0939             0.0175
# 2                0.0693                  0.1413             0.0781
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0      0.0952                 0.0000               0.1046
# 1      0.0934                 0.0695               0.1184
# 2      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media  total_matriculados
# 0                 0.1376            0.0204            314.9786
# 1                 0.0848            0.0316           2364.1226
# 2                 0.1025            0.0154            654.9528

# %%
## ordenar tablas 

columnas_orden = list(df_raw.columns)
columnas_orden.insert(6, columnas_orden.pop(columnas_orden.index('total_matriculados')))

df_raw = df_raw[columnas_orden]
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  total_matriculados  tasa_matriculaci_n_5_16  \
# 0           503.0            314.9786                   0.6262
# 1          4438.0           2364.1226                   0.5327
# 2          2014.0            654.9528                   0.3252
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0          0.6262                     0.4419                   0.6333
# 1          0.5327                     0.3391                   0.4889
# 2          0.3252                     0.1758                   0.2533
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                     0.5153                0.4023           0.6680
# 1                     0.4490                0.2130           0.6298
# 2                     0.2643                0.1075           0.3858
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                      0.5814                    0.7286
# 1                      0.5420                    0.6519
# 2                      0.3636                    0.3728
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                      0.6687                 0.5632     0.0119
# 1                      0.6960                 0.4854     0.0556
# 2                      0.4610                 0.2616     0.0785
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0              0.0131                0.0000      0.9226
# 1              0.0499                0.0611      0.8767
# 2              0.0843                0.0636      0.8268
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                 0.0000               0.9673                 0.8349
# 1                 0.0000               0.8790                 0.8450
# 2                 0.0333               0.8464                 0.7951
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0            0.9388       0.0655                  0.0000
# 1            0.9298       0.0678                  0.0000
# 2            0.8750       0.0947                  0.0333
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                0.0196                  0.1651             0.0204
# 1                0.0711                  0.0939             0.0175
# 2                0.0693                  0.1413             0.0781
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0      0.0952                 0.0000               0.1046
# 1      0.0934                 0.0695               0.1184
# 2      0.0865                 0.0667               0.0904
#
#    repitencia_secundaria  repitencia_media
# 0                 0.1376            0.0204
# 1                 0.0848            0.0316
# 2                 0.1025            0.0154

# %% [markdown]
# ### 10. Cambiar nombres columnas

# %%
nuevos_nombres = {
    'a_o': 'anio',
    'c_digo_municipio': 'codigo_municipio',
    'municipio': 'nombre_municipio',
    'c_digo_departamento': 'codigo_departamento',
    'departamento': 'nombre_departamento',
    'poblaci_n_5_16': 'poblacion_5_16',
    'total_matriculados': 'total_matriculados',
    'tasa_matriculaci_n_5_16': 'tasa_matriculacion_5_16',
    'cobertura_neta': 'cobertura_neta_total',
    'cobertura_neta_transici_n': 'cobertura_neta_transicion',
    'cobertura_neta_primaria': 'cobertura_neta_primaria',
    'cobertura_neta_secundaria': 'cobertura_neta_secundaria',
    'cobertura_neta_media': 'cobertura_neta_media',
    'cobertura_bruta': 'cobertura_bruta_total',
    'cobertura_bruta_transici_n': 'cobertura_bruta_transicion',
    'cobertura_bruta_primaria': 'cobertura_bruta_primaria',
    'cobertura_bruta_secundaria': 'cobertura_bruta_secundaria',
    'cobertura_bruta_media': 'cobertura_bruta_media',
    'deserci_n': 'tasa_desercion_total',
    'deserci_n_primaria': 'tasa_desercion_primaria',
    'deserci_n_secundaria': 'tasa_desercion_secundaria',
    'aprobaci_n': 'tasa_aprobacion_total',
    'aprobaci_n_transici_n': 'tasa_aprobacion_transicion',
    'aprobaci_n_primaria': 'tasa_aprobacion_primaria',
    'aprobaci_n_secundaria': 'tasa_aprobacion_secundaria',
    'aprobaci_n_media': 'tasa_aprobacion_media',
    'reprobaci_n': 'tasa_reprobacion_total',
    'reprobaci_n_transici_n': 'tasa_reprobacion_transicion',
    'reprobaci_n_primaria': 'tasa_reprobacion_primaria',
    'reprobaci_n_secundaria': 'tasa_reprobacion_secundaria',
    'reprobaci_n_media': 'tasa_reprobacion_media',
    'repitencia': 'tasa_repitencia_total',
    'repitencia_transici_n': 'tasa_repitencia_transicion',
    'repitencia_primaria': 'tasa_repitencia_primaria',
    'repitencia_secundaria': 'tasa_repitencia_secundaria',
    'repitencia_media': 'tasa_repitencia_media'
}

df_raw.rename(columns=nuevos_nombres, inplace=True) ## aca renombra
df_raw.head(2)
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            314.9786
# 1            Guaviare          4438.0           2364.1226
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                   0.6262                0.6262                     0.4419
# 1                   0.5327                0.5327                     0.3391
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                   0.6333                     0.5153                0.4023
# 1                   0.4889                     0.4490                0.2130
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                 0.6680                      0.5814
# 1                 0.6298                      0.5420
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                    0.7286                      0.6687
# 1                    0.6519                      0.6960
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                 0.5632                0.0119                   0.0131
# 1                 0.4854                0.0556                   0.0499
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                     0.0000                 0.9226
# 1                     0.0611                 0.8767
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                         0.0                    0.9673
# 1                         0.0                    0.8790
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                      0.8349                 0.9388                  0.0655
# 1                      0.8450                 0.9298                  0.0678
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                          0.0                     0.0196
# 1                          0.0                     0.0711
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                       0.1651                  0.0204                 0.0952
# 1                       0.0939                  0.0175                 0.0934
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                      0.0000                    0.1046
# 1                      0.0695                    0.1184
#
#    tasa_repitencia_secundaria  tasa_repitencia_media
# 0                      0.1376                 0.0204
# 1                      0.0848                 0.0316

# %% [markdown]
# La base de datos ya ha sido completamente analizada y limpiada, y está lista para el proceso de ejercicio en SQL. Este ejercicio se centrará en la construcción del modelo dimensional y en la resolución de preguntas.
